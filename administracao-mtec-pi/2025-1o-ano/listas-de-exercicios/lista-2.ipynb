# %% [markdown]
# <sub>Matemática</sub>
# <hr style="margin-top:-1em;" height="1px">
#
# &nbsp;
#
# <h1 align="center"><sup>—{ Relações; Funções; Função Afim, Linear, Identidade e Constante }—</sup><br>2ª Lista de Exercícios - 1º Ano</h1>
# <h4 align="center">Prof. Eduardo Ono</h4>
# <h5 align="center">Atualizado em: 05/05/2025</h5>
#
# &nbsp;

# %% [markdown]
# <hr>
#
# ENEM-2023-v154. &nbsp; Um investidor iniciante observou o gráfico que apresenta a evolução dos valores de duas criptomoedas $\text{A}$ e $\text{B}$ em relação ao tempo.
#
# <h4 align="center">
#
# ![image.png](attachment:image.png)
#
# </h4>
#
# &emsp; Durante horas consecutivas, esses valores foram observados em nove instantes, representados por horas
# exatas. Em quantos desses instantes a criptomoeda $\text{A}$ estava mais valorizada do que a criptomoeda $\text{B}$?
#
# A) $\,3$<br>
# B) $\,4$ &check;<br>
# C) $\,6$<br>
# D) $\,7$<br>
# E) $\,9$<br>
#
# &nbsp;
#
# __RESOLUÇÃO__
#
# * <https://github.com/eduardo-ono/Fundamentos-de-Matematica/blob/main/conteudo/03-funcoes/funcoes-afins-lineares-constantes-identidade/exercicios-resolvidos/enem-2023-v154.ipynb>
#
# __REFERÊNCIAS__
#
# * <https://download.inep.gov.br/enem/provas_e_gabaritos/2023_PV_impresso_D2_CD12.pdf#page=22>

# %% [markdown]
# <hr>
#
# __ENEM-2023-v145__. &nbsp; Para concretar a laje de sua residência, uma pessoa contratou uma construtora. Tal empresa informa que o preço $y$ do concreto bombeado é composto de duas partes: uma fixa, chamada de taxa de bombeamento, e uma variável, que depende do volume $x$ de concreto utilizado. Sabe-se que a taxa de bombeamento custa $\,\text{R\$ 500,00}\,$ e que o metro cúbico do concreto bombeado é de $\text{R\$ 250,00}$.
#
# &emsp; A expressão que representa o preço $y$ em função do volume $x$, em metro cúbico, é
#
# A) $\ y = 250\,x$<br>
# B) $\ y = 500\,x$<br>
# C) $\ y = 750\,x$<br>
# D) $\ y = 250\,x + 500$ &check;<br>
# E) $\ y = 500\,x + 250$<br>
#
# &nbsp;
#
# __REFERÊNCIAS__
#
# * <https://download.inep.gov.br/enem/provas_e_gabaritos/2023_PV_impresso_D2_CD12.pdf#page19>

# %% [markdown]
# <hr>
#
# __ENEM-2024-v161__. &nbsp; Uma empresa produz mochilas escolares sob encomenda. Essa empresa tem um custo total de produção, composto por um custo fixo, que não depende do número de mochilas, mais um custo variável, que é proporcional ao número de mochilas produzidas. O custo total cresce de forma linear, e a tabela apresenta esse custo para três quantidades de mochilas produzidas.
#
# | Quantidade de<br>mochilas | $30$ | $50$ | $100$ |
# | :-: | :-: | :-: | :-: |
# | __Custo total (R$)__ | $1\,050,00$ | $1\,650,00$ | $3\,150,00$ |
#
# &emsp; O custo total, em real, para a produção de 80 mochilas será
#
# A) &nbsp; $2\,400,00$.<br>
# B) &nbsp; $2\,520,00$.<br>
# C) &nbsp; $2\,550,00$. &check;<br>
# D) &nbsp; $2\,700,00$.<br>
# E) &nbsp; $2\,800,00$.<br>
#
# &nbsp;
#
# __RESOLUÇÃO__
#
# * <https://github.com/eduardo-ono/Fundamentos-de-Matematica/blob/main/conteudo/03-funcoes/funcoes-afins-lineares-constantes-identidade/exercicios-resolvidos/enem-2024-v161.ipynb>
#
# __REFERÊNCIAS__
#
# * <https://download.inep.gov.br/enem/provas_e_gabaritos/2024_PV_impresso_D2_CD8.pdf#page=23>

# %% [markdown]
# <hr>
#
# __ENEM-2024-v158__. &nbsp; Uma doceira vende e entrega, em seu bairro, porções de 100 g de docinhos de aniversário. Atualmente, a taxa única de entrega é $\,\text{R\$ 10,00}$, e o valor cobrado por uma porção é $\,\text{R\$ 25,00}$. Por uma estratégia de vendas, a partir da próxima semana, a taxa única de entrega será $\,\text{R\$ 15,00}$, e um novo valor será cobrado por uma porção, de maneira que o valor total a ser pago por um cliente na compra de 5 porções permaneça o mesmo.
#
# &emsp; A partir da próxima semana, qual será o novo valor cobrado, em real, por uma porção?
#
# A) $\ 12,50$<br>
# B) $\ 20,00$<br>
# C) $\ 24,00$ &check;<br>
# D) $\ 30,00$<br>
# E) $\ 37,50$<br>
#
# &nbsp;
#
# __RESOLUÇÃO__
#
# * <https://github.com/eduardo-ono/Fundamentos-de-Matematica/blob/main/conteudo/03-funcoes/funcoes-afins-lineares-constantes-identidade/exercicios-resolvidos/enem-2024-v158.ipynb>
#
# __REFERÊNCIAS__
#
# * <https://download.inep.gov.br/enem/provas_e_gabaritos/2024_PV_impresso_D2_CD8.pdf#page=22>

# %% [markdown]
# <hr>
#
# __ENEM-2024-v166__. &nbsp; As receitas anuais obtidas por uma indústria no período de 2014 a 2021, em milhão de reais, foram registradas, por pontos, em um gráfico. Nele, também está representada a reta que descreve a tendência de evolução das receitas. Essa reta pode ser utilizada para estimar as receitas dos anos seguintes.
#
# <figure style="text-align:center">
#
# ![image.png](attachment:image.png)
#
# </figure>
#
# &emsp; A estimativa da receita, em milhão de reais, dessa indústria, para o ano de 2026, obtida a partir dessa reta de tendência, é
#
# a) $\,7$.<br>
# b) $\,8$. &check;<br>
# c) $\,9$.<br>
# d) $\,10$.<br>
# e) $\,11$.<br>
#
# &nbsp;
#
# __REFERÊNCIAS__
#
# * <https://download.inep.gov.br/enem/provas_e_gabaritos/2024_PV_impresso_D2_CD8.pdf#page=24>

# %% [markdown]
# <hr>
#
# __ENEM-2022-v156__. &nbsp; Uma loja de roupas fixou uma meta de vendas de 77000 reais para um determinado mês de 30 dias. O gráfico mostra o volume de vendas dessa loja, em real, nos dez primeiros dias do mês e entre o dia dez e o dia vinte desse mês, nos seus dois únicos setores (infantil e adulto). Suponha que a variação no volume de vendas, para o período registrado, tenha se dado de forma linear, como mostrado no gráfico, e que essa tendência se mantenha a mesma para os próximos dez dias.
#
# <h4 align="center">
#
# ![image.png](attachment:image.png)
#
# </h4>
#
# &emsp; Ao final do trigésimo dia, quanto faltará no volume de vendas, em real, para que a meta fixada para o mês seja alcançada?
#
# A)&nbsp; $5\,000$<br>
# B)&nbsp; $7\,000$<br>
# C)&nbsp; $11\,000$ &check;<br>
# D)&nbsp; $18\,000$<br>
# E)&nbsp; $29\,000$<br>
#
# &nbsp;
#
# __RESOLUÇÃO__
#
# * <https://github.com/eduardo-ono/Fundamentos-de-Matematica/blob/main/conteudo/03-funcoes/funcoes-afins-lineares-constantes-identidade/exercicios-resolvidos/enem-2022-v156.ipynb>
#
# __REFERÊNCIAS__
#
# * <https://download.inep.gov.br/enem/provas_e_gabaritos/2022_PV_impresso_D2_CD12.pdf#page=22>

# %% [markdown]
# <hr>
#
# __ENEM-2021-v165__. &nbsp; A receita $R$ de uma empresa ao final de um mês é o dinheiro captado com a venda de mercadorias ou com a prestação de serviços nesse mês, e a despesa $D$ é todo o dinheiro utilizado para pagamento de salários, contas de água e luz, impostos, entre outros. O lucro mensal obtido ao final do mês é a diferença entre a receita e a despesa registradas no mês. O gráfico apresenta as receitas e despesas, em milháo de real, de uma empresa ao final dos cinco primeiros meses de um dado ano.
#
# ![image.png](attachment:image.png)
#
# &emsp; A previsão para os próximos meses é que o lucro mensal não seja inferior ao maior lucro obtido até o mês de maio. Nessas condições, o lucro mensal para os próximos meses deve ser maior ou igual ao do mês de
#
# A)&nbsp; janeiro.<br>
# B)&nbsp; fevereiro. &check;<br>
# C)&nbsp; março.<br>
# D)&nbsp; abril.<br>
# E)&nbsp; maio.<br>
#
# &nbsp;
#
# __REFERÊNCIAS__
#
# * <https://download.inep.gov.br/enem/provas_e_gabaritos/2021_PV_impresso_D2_CD12.pdf#page=26>

# %% [markdown]
# <hr>
#
# __ENEM-2017-v160__. &nbsp; A base de cálculo do imposto de renda é a parte dos rendimentos recebidos pelo contribuinte sobre a qual incide o imposto. Ela é obtida após serem descontadas, dos rendimentos, as deduções legais.
#
# &emsp; No ano de 2008, se a base de cálculo de um contribuinte teve um valor de até $\text{R\$ } 16\,473{,}72$, 0 contribuinte foi isento do imposto de renda. Se a base de cálculo ficou entre $\text{R\$ } 16\,473{,}72$ e $\text{R\$ } 32\,919{,}00$, o imposto devido foi de $15\%$ sobre o que excedeu $\text{R\$ } 16\,473{,}72$. Por fim, se a base de cálculo ultrapassou $\text{R\$ } 32\,919,00$, 0 imposto devido é dado pela soma de $\text{R\$ } 2\,466{,}79$ (correspondendo a $15\%$ da diferença $32\,919{,}00 - 16\,473{,}72$) mais $27,5\%$ do que excedeu $\text{R\$ } 32\,919{,}00$.
#
# &emsp; O gerente de um escritório de contabilidade pediu a um estagiário que identificasse o gráfico que descrevia o valor do imposto devido, para o ano de 2008, como função da base de cálculo, apresentando-lhe cinco gráficos, sem qualquer outra informação ou valores numéricos.
#
# ![image.png](attachment:image.png)
#
# &emsp; Admitindo que um desses gráficos corresponda ao pedido do gerente, qual é esse gráfico?
#
# A)&nbsp; $\text{I}$<br>
# B)&nbsp; $\text{II}$<br>
# C)&nbsp; $\text{III}$<br>
# D)&nbsp; $\text{IV}$<br>
# E)&nbsp; $\text{V}$<br>
#
# &nbsp;
#
# __REFERÊNCIAS__
#
# * <https://download.inep.gov.br/educacao_basica/enem/provas/2017/2017_PV_impresso_D2_CD12.pdf#page=24>
