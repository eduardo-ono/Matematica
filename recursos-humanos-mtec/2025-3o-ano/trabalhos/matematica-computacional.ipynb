# %% [markdown]
# ## Funções Polinomiais de 3º Grau

# %% [markdown]
# | Grupo | Função |
# | :-: | --- |
# | 1 | $f(x) = x^3 + 7x^2 - 3x - 8$ |
# | 2 | $f(x) = x^3 + 6x^2 - 2x - 5$ |
# | 3 | $f(x) = x^3 + 4x^2 - 2x - 5$ |
# | 4 | $f(x) = x^3 + 2x^2 - 7x - 2$ |
# | 5 | $f(x) = x^3 + 3x^2 - 5x - 4$ |
# | 6 | $f(x) = x^3 + 5x^2 - 2x - 4$ |
# | 7 | $f(x) = x^3 + 5x^2 - 2x - 6$ |

# %% [markdown]
# ---
# ## Vídeo para a Resenha (individual)
#
# | Thumb | Descrição |
# | :-: | --- |
# | ![img](https://img.youtube.com/vi/_hobgOFDekg/default.jpg) | <sup>[Filipe Deschamps]</sup><br>[__Por Que Tudo Parece Ter Menos Graça Hoje Em Dia__](https://www.youtube.com/watch?v=_hobgOFDekg)<br><sub>(18:23, YouTube, 03/Ago/2020)</sub> |
