# %% [markdown]
# <sub>Matemática</sub>
# <hr style="margin-top:-1em;" height="1px">
#
# &nbsp;
#
# <h1 align="center"><sup>—{ Matrizes, Determinantes e Sistemas Lineares (3x3) }—</sup><br>3ª Lista de Exercícios - 2º Ano</h1>
# <h4 align="center">Prof. Eduardo Ono</h4>
# <h5 align="center">Atualizado em: 01/06/2025</h5>
#
# &nbsp;

# %% [markdown]
# <hr>
#
# __EsFAO__. &nbsp; Qual o valor de $k$ para que o sistema
#
# $$
# \left\{
#   \begin{matrix}
#   \ x & & & - & 3z & = & -3 \\
#   \ 2x & + & ky & - & z & = & -2 \\
#   \ x & + & 2y & + & kz & = & 1
#   \end{matrix}
# \right.
# $$
#
# não tenha nenhuma solução?
#
# &nbsp;
#
# __REFERÊNCIAS__
#
# | Thumb | Descrição |
# | :-: | --- |
# | ![img](https://img.youtube.com/vi/RtMuMuDtlr0/default.jpg) | <sup>[Problemas Resolvidos]</sup><br>[__1000QMat \| #40 – EsFAO – Sistemas Lineares__](https://www.youtube.com/watch?v=RtMuMuDtlr0)<br><sub>(17:41, YouTube, dd/Mon/yyyy)</sub> |

# %% [markdown]
# <hr>
#
# __EsPCEx-2022-q11__. &nbsp; Sejam $\lambda$ um parâmetro real e $\varepsilon$ o sistema linear abaixo, com incógnitas $a$, $b$ e $c$.
#
# $$
# \varepsilon = \left\{
#   \begin{matrix}
#   \ \lambda a & - & b & + & c & = & 3 \\
#   \ a & + & \lambda b & + & c & = & \lambda \\
#   \ a & + & b & + & c & = & 1
#   \end{matrix}
# \right.
# $$
#
# &emsp; É correto afirmar que
#
# <sample>a)</sample>&nbsp; $\varepsilon$ será possível e determinado se $\,\lambda = 0\,$ ou $\,\lambda = 1\,$.<br>
# <sample>b)</sample>&nbsp; $\varepsilon$ será possível e indeterminado se, e somente se, $\,\lambda = 0\,$ ou $\,\lambda = 1\,$.<br>
# <sample>c)</sample>&nbsp; $\varepsilon$ será impossível se $\,\lambda = -1\,$ ou $\,\lambda = 0\,$.<br>
# <sample>d)</sample>&nbsp; $\varepsilon$ será possível e indeterminado se $\,\lambda = -1\,$ ou $\,\lambda = 0\,$.<br>
# <sample>e)</sample>&nbsp; $\varepsilon$ será impossível se, e somente se, $\,\lambda = 0\,$ ou $\,\lambda = 1\,$.<br>
#
# &nbsp;
#
# __REFERÊNCIAS__
#
# | Thumb | Descrição |
# | :-: | --- |
# | ![img](https://img.youtube.com/vi/HGXuVHZp5Ek/default.jpg) | <sup>[Conduta Militar]</sup><br>[__A questão mais TRABALHOSA resolvida do jeito SIMPLES__](https://www.youtube.com/watch?v=HGXuVHZp5Ek)<br><sub>(10:43, YouTube, 23/Set/2022)</sub> |

# %% [markdown]
# <hr>
#
# __ITA__. &nbsp; Os dados experimentais da tabela abaixo correspondem às concentrações de uma substância química medida em intervalos de 1 segundo. Assumindo que a linha que passa pelos três pontos experimentais é uma parábola, tem-se que a concentração (em moles) após 2,5 segundo é:
#
# | Tempo (s) | Concentração (moles) |
# | :-: | :-: |
# | 1 | 3,00 |
# | 2 | 5,00 |
# | 3 | 1,00 |
#
# <sample>a)</sample>&nbsp; $3,60$<br>
# <sample>b)</sample>&nbsp; $3,65$<br>
# <sample>c)</sample>&nbsp; $3,70$<br>
# <sample>d)</sample>&nbsp; $3,75$ &check;<br>
# <sample>e)</sample>&nbsp; $3,80$<br>
#
# &nbsp;
#
# __REFERÊNCIAS__
#
# | Thumb | Descrição |
# | :-: | --- |
# | ![img](https://img.youtube.com/vi/T8CmjxwmjOg/default.jpg) | <sup>[Fábrica de Matemática]</sup><br>[__ITA - Função quadrática - Sistemas Lineares__](https://www.youtube.com/watch?v=T8CmjxwmjOg)<br><sub>(8:36, YouTube, 05/Abr/2024)</sub> |
