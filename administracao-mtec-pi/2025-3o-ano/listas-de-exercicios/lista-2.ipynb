# %% [markdown]
# <sub>Matemática</sub>
# <hr style="margin-top:-1em;" height="1px">
#
# &nbsp;
#
# <h1 align="center"><sup>—{ Cilindros, Cones e Esferas }—</sup><br>2ª Lista de Exercícios - 3º Ano</h1>
# <h4 align="center">Prof. Eduardo Ono</h4>
# <h5 align="center">Atualizado em: 01/06/2025</h5>
#
# &nbsp;

# %% [markdown]
# <hr>
#
# __EsPCEx-2016-q20__. &nbsp; Corta-se de uma circunferência de raio 4 cm, um setor circular de ângulo $\cfrac{\pi}{2}$ rad (ver desenho ilustrativo), onde o ponto $C$ é centro da circunferência. Um cone circular reto é construído a partir desse setor circular ao se juntar os rais $\,CA\,$ e $\,CB$. O volume desse cone, em cm<sup>3</sup>, é igual a
#
# <figure style="display:flex; justify-content:center;">
#
# ![image.png](attachment:image.png)
#
# </figure>
#
# <sample>A)</sample>&nbsp; $\cfrac{\sqrt{3}}{3}\,\pi$ <br><br>
# <sample>B)</sample>&nbsp; $\cfrac{\sqrt{3}}{5}\,\pi$<br><br>
# <sample>C)</sample>&nbsp; $\cfrac{\sqrt{15}}{3}\,\pi$ &check;<br><br>
# <sample>D)</sample>&nbsp; $\cfrac{\sqrt{15}}{5}\,\pi$<br><br>
# <sample>E)</sample>&nbsp; $\cfrac{\sqrt{5}}{5}\,\pi$<br>
#
# &nbsp;
#
# __REFERÊNCIAS__
#
# | Thumb | Descrição |
# | :-: | --- |
# | ![img](https://img.youtube.com/vi/2syYzK9cPNQ/default.jpg) | <sup>[cesar rosa]</sup><br>[__EsPCEx 2016 - Questão de Geometria Espacial e Plana__](https://www.youtube.com/watch?v=2syYzK9cPNQ)<br><sub>(7:56, YouTube, 31/Out/2016)</sub> |

# %% [markdown]
# <hr>
#
# | Thumb | Descrição |
# | :-: | --- |
# | ![img](https://img.youtube.com/vi/_7CmT3ik_4o/default.jpg) | <sup>[Universo Narrado Militares]</sup><br>[__EsPCEx sempre brincando com a Geometria Espacial__](https://www.youtube.com/watch?v=_7CmT3ik_4o)<br><sub>(14:12, YouTube, 04/Jun/2025)</sub> |
