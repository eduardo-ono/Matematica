# %% [markdown]
# <sub>Matemática</sub>
# <hr style="margin-top:-1em;" height="1px">
#
# &nbsp;
#
# <h1 align="center"><sup>—{ Funções; Função Quadrática (Função Polinomial do 2º Grau) }—</sup><br>3ª Lista de Exercícios - 1º Ano</h1>
# <h4 align="center">Prof. Eduardo Ono</h4>
# <h5 align="center">Atualizado em: 29/05/2025</h5>
#
# &nbsp;

# %% [markdown]
# ### Revisão da Teoria, Exercícios Básicos e Macetes
#
# | Thumb | Descrição |
# | :-: | --- |
# | ![img](https://img.youtube.com/vi/Q2UqPk0EbJQ/default.jpg) | <sup>[Equaciona Com Paulo Pereira]</sup><br>[__Revisão Função Quadrática - Teoria, Exercícios e Macetes__](https://www.youtube.com/watch?v=Q2UqPk0EbJQ)<br><sub>(39:15, YouTube, 08/Jan/2019)</sub> |

# %% [markdown]
# <hr>
#
# &nbsp; Construir os gráficos das funções $\,f: \mathbb{R} \longrightarrow \mathbb{R}\,$, definida por $\,f(x) = x^2 - 2x - 3\,$, e $\,g: \mathbb{R} \longrightarrow \mathbb{R}\,$, definida por $\,g(x) = -2x^2 + x + 3\,$.
#
# &nbsp;
#
# __REFERÊNCIAS__
#
# | Thumb | Descrição |
# | :-: | --- |
# | ![img](https://img.youtube.com/vi/aIOKZ0rFzS4/default.jpg) | <sup>[Gis com Giz Matemática]</sup><br>[__GRÁFICO DA FUNÇÃO QUADRÁTICA \| SEGUNDO GRAU 2º \| PARÁBOLA - AULA 4__](https://www.youtube.com/watch?v=aIOKZ0rFzS4)<br><sub>(20:53, YouTube, 12/Jul/2021)</sub> |

# %% [markdown]
# <hr>
#
# __exr-2018-12-05__. &nbsp; Determine a equação da parábola de eixo de simetria vertical e que passa pelos seguintes pontos:
#
# a) &nbsp; $A(0, 3), \ B(1, 0) \ \text{ e } \ C(2, -1)$
#
# b) &nbsp; $A(0, 1), \ B(-1, -3) \ \text{ e } \ C(2, 3)$
#
# &nbsp;
#
# __REFERÊNCIAS__
#
# | Thumb | Descrição |
# | :-: | --- |
# | ![img](https://img.youtube.com/vi/hXJH1g10mlI/default.jpg) | <sup>[Problemas Resolvidos]</sup><br>[__MFUNA | GACo4 - A equação da parábola a partir de 3 PONTOS DADOS__](https://www.youtube.com/watch?v=hXJH1g10mlI)<br><sub>(9:29, YouTube, 05/Dez/2018)</sub> |
